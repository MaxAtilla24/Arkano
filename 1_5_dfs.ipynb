# %% [markdown]
# <a href="https://colab.research.google.com/github/MaxAtilla24/Arkano/blob/main/1_5_dfs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Depth-First Search (DFS) algorithm
#
# Here, we'll demonstrate the Depth-First Search (DFS) algorithm using a simple graph.
#
# <img src="https://drive.google.com/uc?export=view&id=1o3kjqYSdIbtwM59xDT3S0Z3aArtFF5vE" width="400">

# %%
# Example graph of nodes
graph = {
    "A": ["B", "C"],
    "B": ["D", "E"],
    "C": ["F", "G"],
    "D": [],
    "E": [],
    "F": [],
    "G": []
}

# %% [markdown]
# # Depth-First Search

# %%
# Depth-First Search
def dfs(graph, start, visited=None):
    if visited is None:
        visited = []

    visited.append(start)
    for neighbor in graph[start]:
        if neighbor not in visited:
            dfs(graph, neighbor, visited)

    return visited

# Call the DFS functions and print results
visited_nodes_dfs = dfs(graph, "A")

print("DFS - Visited nodes:", visited_nodes_dfs)
# Out:
# DFS - Visited nodes: ['A', 'B', 'D', 'E', 'C', 'F', 'G']

# %% [markdown]
# # Visualizing the Graph

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Example graph of nodes
graph = {
    "A": ["B", "C"],
    "B": ["D", "E"],
    "C": ["F", "G"],
    "D": [],
    "E": [],
    "F": [],
    "G": []
}

G = nx.DiGraph(graph)

# Positions of the nodes for a tree-like visualization
pos = {"A": (0, 0), "B": (-1, -1), "C": (1, -1), "D": (-2, -2), "E": (0, -2), "F": (0, -3), "G": (2, -2)}

# Graph with node labels
nx.draw(G, pos, with_labels=True, node_color="lightblue", font_size=12, font_weight="bold", node_size=1000)
plt.title("Graph")
plt.show()

# %% [markdown]
# # Visualizing Node Traversals

# %%
# Node color based on traversal order
def draw_traversal_order(G, pos, traversal_order, title):
    color_map = []
    for node in G:
        if node in traversal_order:
            color_map.append(plt.cm.Blues((traversal_order.index(node) + 1) / len(traversal_order)))
        else:
            color_map.append("lightgray")

    nx.draw(G, pos, with_labels=True, node_color=color_map, font_size=12, font_weight="bold", node_size=1000)
    plt.title(title)
    plt.show()

# %%
# DFS traversal
visited_nodes_dfs = dfs(graph, "A")
print("DFS - Visited nodes:", visited_nodes_dfs)
draw_traversal_order(G, pos, visited_nodes_dfs, "DFS Traversal")
# Out:
# DFS - Visited nodes: ['A', 'B', 'D', 'E', 'C', 'F', 'G']
